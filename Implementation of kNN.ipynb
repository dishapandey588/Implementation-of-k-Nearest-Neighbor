# %%
pip install -U scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.datasets import make_classification
from sklearn.datasets import make_regression

# %%
X, y = make_classification(n_samples=100,n_features=10,  n_classes = 3, n_informative= 5)
X
# Out:
# array([[ 1.14382239e+00, -4.02537715e-01,  8.14777740e-01,
#          1.07590345e+00, -1.60532809e+00,  8.82189329e-01,
#         -1.48483225e+00, -1.54158024e-01, -1.27751766e+00,
#          2.94703923e-01],
#        [-1.94639404e+00,  1.00191025e+00,  1.98780663e+00,
#         -8.62364188e-01, -4.25618098e+00, -1.67645233e+00,
#         -1.08840529e+00, -1.67040629e+00,  1.44009317e+00,
#          3.97406418e+00],
#        [ 2.84804464e+00, -2.07628631e+00,  1.02191957e+00,
#          9.05687661e-01, -6.59647012e+00, -2.30550696e+00,
#         -7.70928950e-01,  1.23800002e+00,  1.50774606e+00,
#          2.62935392e+00],
#        [ 1.53913036e+00,  1.11010582e+00,  1.92192462e+00,
#          3.47118197e-01, -3.76596328e+00, -7.11553771e-02,
#         -5.67368649e-01, -9.86443381e-01,  1.20824568e+00,
#          1.58268107e+00],
#        [ 4.73961281e-01, -6.86192075e-01,  2.64292272e-01,
#          1.23958209e+00, -2.85034949e+00, -4.85948206e-01,
# ...

# %%
y
# Out:
# array([1, 2, 0, 0, 1, 1, 2, 2, 0, 1, 0, 2, 2, 0, 0, 2, 1, 2, 0, 1, 0, 1,
#        1, 2, 1, 1, 2, 1, 2, 2, 1, 0, 1, 1, 2, 1, 0, 2, 2, 1, 2, 2, 0, 1,
#        0, 0, 2, 2, 0, 0, 1, 1, 0, 0, 0, 2, 0, 0, 2, 0, 2, 1, 1, 0, 1, 2,
#        0, 2, 2, 1, 1, 0, 2, 0, 2, 1, 0, 1, 0, 0, 0, 0, 2, 2, 1, 0, 0, 1,
#        1, 2, 1, 1, 2, 2, 2, 1, 2, 0, 0, 1])

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(X[:, 0], X[:, 1], marker="o", c=y, s=40)

# %%
X,y = make_regression(n_samples = 100, n_features=10, n_informative= 5) 
X
# Out:
# array([[ 4.91539048e-01, -3.62102403e-01, -4.49162950e-01,
#          2.04716928e-01,  5.49320450e-01,  7.21147901e-01,
#          1.07074955e-01,  1.51902208e+00, -5.54674773e-01,
#          7.54839083e-01],
#        [-2.65937465e-01, -3.92239403e-01,  9.09557065e-01,
#         -4.95498241e-02,  6.47136018e-01,  6.95123028e-01,
#          3.09599361e-01, -2.95141132e-02, -3.65109193e-01,
#         -1.24141702e+00],
#        [ 5.94804011e-01,  2.48828541e-01,  1.80809057e-01,
#          1.12820474e-01, -3.68709590e-01, -2.62272983e-01,
#          1.59808906e+00, -2.24733573e-01,  1.37907231e+00,
#         -5.13765311e-01],
#        [-2.18153226e-01, -6.24430703e-01, -7.16670873e-01,
#         -1.31611341e+00,  5.56190060e-01, -7.31528336e-02,
#          2.12979708e-01, -7.45911179e-01, -4.51470043e-01,
#          8.54038539e-02],
#        [ 6.63964795e-01,  2.89295763e-01,  1.51351016e+00,
#         -6.99390650e-01,  3.60252957e-01,  1.03605982e+00,
# ...

# %%
y
# Out:
# array([ 130.59214809,   63.78641289,  -31.21211732,  -73.94084   ,
#         145.66138375,   78.46515321,   29.46872728,  208.57100525,
#        -114.54513656,  -47.50280425,   38.85213528,  -55.20735067,
#          61.71860645, -187.78346285,    2.30422866, -131.69032719,
#        -126.31025557,   15.80538348,   77.62578576,   57.66995298,
#          29.89928721,  -20.59455921, -349.54435555,   90.65624653,
#         -57.64656823,   68.03901744, -238.75132572,  -39.80989455,
#          86.74206198,  -20.9462396 ,  -20.57245745, -306.91987228,
#          36.69787997,  163.37531061,  346.17157855,   12.92855433,
#          65.47340556,  -31.39473134, -210.90652919,  152.35901149,
#         -46.02675405,  -58.14553938,  -79.84906991,   15.56263872,
#        -124.3246788 , -109.37356652,   -3.45830344,  -17.52712708,
#         -74.75013545, -108.61157315,  -75.16814581, -259.513588  ,
#        -133.06470369,   71.33381698,  -85.93367679,  154.57594061,
# ...

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(X[:, 0], X[:, 1], marker="o", c=y, s=40)

# %%
import seaborn as sns
explore = pd.DataFrame(dict(Input_1=X[:,0], Input_2=X[:,1], Output=y))
explore
explore.describe()
sns.jointplot(x=explore["Input_1"], y=explore["Output"], kind='hex', marginal_kws=dict(bins=30, fill=True))
plt.show()

# %%
conda install matplotlib
# Out:
# ...
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::scikit-learn-intelex==2021.3.0=py39hecd8cb5_0
#   - defaults/osx-64::anaconda==2021.11=py39_0
# done
#
# ## Package Plan ##
#
#   environment location: /Users/dishapandey/opt/anaconda3
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2021.11  |           py39_0           7 KB
#     anaconda-custom            |           py39_1           4 KB
#     ca-certificates-2022.3.29  |       hecd8cb5_0         118 KB
#     certifi-2021.10.8          |   py39hecd8cb5_2         152 KB
#     conda-4.12.0               |   py39hecd8cb5_0        14.5 MB
#     openssl-1.1.1n             |       hca72f7f_0         2.2 MB
# ...

# %%
conda install -c conda-forge matplotlib
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/dishapandey/opt/anaconda3
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2021.10.8  |       h033912b_0         139 KB  conda-forge
#     certifi-2021.10.8          |   py39h6e9494a_2         144 KB  conda-forge
#     conda-4.12.0               |   py39h6e9494a_0         1.0 MB  conda-forge
#     matplotlib-3.4.3           |   py39h6e9494a_2           7 KB  conda-forge
#     openssl-1.1.1n             |       h6c3fc93_0         1.9 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.2 MB
#
# The following packages will be UPDATED:
#
# ...

# %%
#Generating 10 new sample points
fig = plt.figure()
ax1 = fig.add_subplot(111)
X2, Y2 = make_classification(n_samples=10, n_features = 10)
ax1.scatter(X2[:, 0], X2[:, 1], marker="o", color = 'purple', s=40)
plt.show()

# %%
X2
# Out:
# array([[-1.35962416, -0.59290445, -1.5368686 , -0.22580698,  0.85711908,
#         -1.52483481, -1.39127349, -0.53520346,  1.13527474, -0.75415573],
#        [-1.2440826 ,  1.14326806, -1.344281  , -1.57018038,  0.53427935,
#          0.5368832 ,  1.19134685,  0.44318185,  0.89572553,  1.0927984 ],
#        [ 1.6541651 ,  0.52629021, -0.89970107,  1.07661321, -0.05220709,
#          0.04407343, -0.09703836,  0.54320322, -1.36465939, -0.24780217],
#        [-1.22729057,  1.19914875,  0.66574611,  0.41537715, -0.02420168,
#          0.88549093, -0.99573829,  0.47666357,  0.87758321,  0.61040646],
#        [ 1.90230891, -1.43011471, -0.41006789,  0.81752328,  1.04652804,
#         -0.74726929,  0.76936839, -0.50166173, -1.39663321,  0.53176488],
#        [-1.25164503, -0.34427952,  0.58501139, -0.15777408,  0.96529502,
#         -0.08021853,  0.32674189, -0.381169  ,  1.02800856,  1.35861527],
#        [ 1.37874729, -1.29610495,  0.94195958, -0.24443239,  0.509126  ,
# ...

# %%
Y2
# Out:
# array([0, 0, 1, 0, 1, 0, 1, 1, 0, 1])

# %%
#Concatenating both sample points and classification dataset
X1 = np.concatenate((X,X2),axis=0)
y1 = np.concatenate((y,Y2),axis=0)

# %%
#Plotting sample points in the same input space as classification dataset

fig = plt.figure()
ax1 = fig.add_subplot(111)
X2, Y2 = make_classification(n_samples=10, n_features = 10)
ax1.scatter(X2[:, 0], X2[:, 1], marker="o", color = 'purple', s=40)
ax1.scatter(X[:, 0], X[:, 1], marker="o", c=y, s=40)
plt.show()

# %%
#https://www.datacamp.com/community/tutorials/k-nearest-neighbor-classification-scikit-learn

from math import sqrt
def dist_between(a, b):
    dist_between = 0.0
    for i in range(len(a)-1):
        dist_between += (a[i] - b[i])**2
    return sqrt(dist_between)
 

def neighbor1(train_data, test, knn_neighbors):
    distances = list()
    
    for train_set in train_data:
        dist = dist_between(test, train_set)
        distances.append((train_set, dist))
    distances.sort(key=lambda tup: tup[1])
    neighbor1 = list()
    
    for i in range(knn_neighbors):
        neighbor1.append(distances[i][0])
    return neighbor1
 
    
data = X1
neighbor1 = neighbor1(data, data[0], 4)

for neighbor in neighbor1:
    print(neighbor)
# Out:
# [ 0.49153905 -0.3621024  -0.44916295  0.20471693  0.54932045  0.7211479
#   0.10707495  1.51902208 -0.55467477  0.75483908]
# [ 0.62255132 -1.4836926  -0.88209617 -0.30383721 -0.1137027  -0.00172957
#  -1.03953584  1.17989306 -0.2156933  -1.68503245]
# [ 0.94441615  0.65933578 -0.75530452  0.29934502  0.17968502 -0.20292427
#   0.28774836  0.47873967  0.35259564 -0.77206338]
# [ 0.99662331 -0.86105952 -1.06559377  0.41096698 -0.12748181  0.3613018
#  -0.96736132  0.9497315   0.67255974 -0.87899301]

# %%
# When k = 1

from math import sqrt

def dist_between(a, b):
    dist_between = 0.0
    
    for i in range(len(a)-1):
        dist_between += (a[i] - b[i])**2
    return sqrt(dist_between)
 
def neighbor1(train, test, knn_neighbors):
    distances = list()
    
    for train_row in train:
        dist = dist_between(test, train_row)
        distances.append((train_row, dist))
    distances.sort(key=lambda tup: tup[1])
    neighbor1 = list()
    
    for i in range(knn_neighbors):
        neighbor1.append(distances[i][0])
    return neighbor1
 
    
data = X1
neighbor1 = neighbor1(data, data[0], 1)

for neighbor in neighbor1:
    print(neighbor)
# Out:
# [ 0.49153905 -0.3621024  -0.44916295  0.20471693  0.54932045  0.7211479
#   0.10707495  1.51902208 -0.55467477  0.75483908]

# %%
# When k = 100

from math import sqrt

def dist_between(a, b):
    dist_between = 0.0
    
    for i in range(len(a)-1):
        dist_between += (a[i] - b[i])**2
    return sqrt(dist_between)
 
def neighbor1(train, test, knn_neighbors):
    distances = list()
    
    for train_row in train:
        dist = dist_between(test, train_row)
        distances.append((train_row, dist))
    distances.sort(key=lambda tup: tup[1])
    neighbor1 = list()
    
    for i in range(knn_neighbors):
        neighbor1.append(distances[i][0])
    return neighbor1
 
    
data = X1
neighbor1 = neighbor1(data, data[0], 100)

for neighbor in neighbor1:
    print(neighbor)
# Out:
# [ 0.49153905 -0.3621024  -0.44916295  0.20471693  0.54932045  0.7211479
#   0.10707495  1.51902208 -0.55467477  0.75483908]
# [ 0.62255132 -1.4836926  -0.88209617 -0.30383721 -0.1137027  -0.00172957
#  -1.03953584  1.17989306 -0.2156933  -1.68503245]
# [ 0.94441615  0.65933578 -0.75530452  0.29934502  0.17968502 -0.20292427
#   0.28774836  0.47873967  0.35259564 -0.77206338]
# [ 0.99662331 -0.86105952 -1.06559377  0.41096698 -0.12748181  0.3613018
#  -0.96736132  0.9497315   0.67255974 -0.87899301]
# [ 0.46063627  0.39746952 -0.01772495  0.28377073 -1.22092067  1.24019687
#   0.40856488  2.21191016 -0.6282462   0.9660491 ]
# [ 0.37985088 -0.70393841  0.20725844 -0.16963835 -0.56860423  0.43635202
#  -1.48531872  1.72306178 -0.12686503 -0.82858573]
# [-0.26593746 -0.3922394   0.90955707 -0.04954982  0.64713602  0.69512303
#   0.30959936 -0.02951411 -0.36510919 -1.24141702]
# [ 1.46242465 -0.51401311  0.47559305  1.78118574 -0.06898934  0.66345075
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
#https://www.datacamp.com/community/tutorials/k-nearest-neighbor-classification-scikit-learn


from itertools import product

p = X1[:,[0,2]] 
q = y1

# Setting the decisions boundaries i.e., k to 1, 10, 100 and 20
a1 = KNeighborsClassifier(n_neighbors=1)
b1 = KNeighborsClassifier(n_neighbors=10)
c1 = KNeighborsClassifier(n_neighbors=100)
d1 = KNeighborsClassifier(n_neighbors=20)
a1.fit(p,q)
b1.fit(p,q)
c1.fit(p,q)
d1.fit(p,q)



# Plotting decision regions
x_min, x_max = p[:, 0].min() - 1, p[:, 0].max() + 1
y_min, y_max = p[:, 1].min() - 1, p[:, 1].max() + 1
aa, bb = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))


f, v = plt.subplots(2, 2, sharex="col", sharey="row", figsize=(10, 3))

for i, j, k in zip(
    product([0, 1], [0, 1]),
    [a1,b1,c1,d1],
    ["KNN (k=1)","KNN (k=10)","KNN (k=100)", "KNN (k=20)"],
):

    Z = j.predict(np.c_[aa.ravel(), bb.ravel()])
    Z = Z.reshape(aa.shape)

    v[i[0], i[1]].contourf(aa, bb, Z, alpha=0.7)
    v[i[0], i[1]].scatter(X1[:, 0], X1[:, 1], c=y1, s=40, cmap = 'inferno')
    v[i[0], i[1]].set_title(k)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/np/x99l3qf95yj2gj7kh2fbrwmm0000gn/T/ipykernel_66295/1753352735.py in <module>
#      12 c1 = KNeighborsClassifier(n_neighbors=100)
#      13 d1 = KNeighborsClassifier(n_neighbors=20)
# ---> 14 a1.fit(p,q)
#      15 b1.fit(p,q)
#      16 c1.fit(p,q)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py in fit(self, X, y)
#     196         self.weights = _check_weights(self.weights)
#     197
# --> 198         return self._fit(X, y)
#     199
#     200     def predict(self, X):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_base.py in _fit(self, X, y)
#     418                     self.outputs_2d_ = True
#     419
# --> 420                 check_classification_targets(y)
#     421                 self.classes_ = []
# ...

# %%
X,y = make_regression(n_samples = 100, n_features=10, n_informative= 5) #same regression dataset as Q2

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(X[:, 0], X[:, 1], marker="o", c=y, s=40)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
X2, Y2 = make_regression(n_samples = 10, n_features=10)
ax1.scatter(X2[:, 0], X2[:, 1], marker="o", color = 'magenta', s=40)
ax1.scatter(X[:, 0], X[:, 1], marker="o", c=y, s=40)
plt.show()

# %%
X1 = np.concatenate((X,X2),axis=0)
y1 = np.concatenate((y,Y2),axis=0)

# %%
#https://www.datacamp.com/community/tutorials/k-nearest-neighbor-classification-scikit-learn

from math import sqrt
def dist_between(a, b):
    dist_between = 0.0
    for i in range(len(a)-1):
        dist_between += (a[i] - b[i])**2
    return sqrt(dist_between)
 

def neighbor1(train_data, test, knn_neighbors):
    distances = list()
    
    for train_set in train_data:
        dist = dist_between(test, train_set)
        distances.append((train_set, dist))
    distances.sort(key=lambda tup: tup[1])
    neighbor1 = list()
    
    for i in range(knn_neighbors):
        neighbor1.append(distances[i][0])
    return neighbor1
 
    
data = X1
neighbor1 = neighbor1(data, data[0], 4)

for neighbor in neighbor1:
    print(neighbor)
# Out:
# [-1.21644785  2.05848389  1.72383351  0.54599482  1.44386319 -1.61702694
#  -1.03924073  1.72190475 -1.74860387  1.75114361]
# [-1.50961234  1.66783478  0.47379626  1.55251026  0.02435629 -1.31846672
#  -0.67640805  1.5967212   0.06914085 -0.52726575]
# [-1.05738939 -0.06374617  0.56023043 -0.10785592  0.39698775 -0.60735472
#  -1.08811951  0.71741358 -0.04461029  1.15022774]
# [-0.51583025  0.58104793  0.53948164  0.66451303  0.1455225  -0.97386557
#   0.45260335  1.62736195  0.64829523 -1.18299696]

# %%
# When k = 1

from math import sqrt

def dist_between(a, b):
    dist_between = 0.0
    
    for i in range(len(a)-1):
        dist_between += (a[i] - b[i])**2
    return sqrt(dist_between)
 
def neighbor1(train, test, knn_neighbors):
    distances = list()
    
    for train_row in train:
        dist = dist_between(test, train_row)
        distances.append((train_row, dist))
    distances.sort(key=lambda tup: tup[1])
    neighbor1 = list()
    
    for i in range(knn_neighbors):
        neighbor1.append(distances[i][0])
    return neighbor1
 
    
data = X1
neighbor1 = neighbor1(data, data[0], 1)

for neighbor in neighbor1:
    print(neighbor)
# Out:
# [-1.21644785  2.05848389  1.72383351  0.54599482  1.44386319 -1.61702694
#  -1.03924073  1.72190475 -1.74860387  1.75114361]

# %%
# When k = 10

from math import sqrt

def dist_between(a, b):
    dist_between = 0.0
    
    for i in range(len(a)-1):
        dist_between += (a[i] - b[i])**2
    return sqrt(dist_between)
 
def neighbor1(train, test, knn_neighbors):
    distances = list()
    
    for train_row in train:
        dist = dist_between(test, train_row)
        distances.append((train_row, dist))
    distances.sort(key=lambda tup: tup[1])
    neighbor1 = list()
    
    for i in range(knn_neighbors):
        neighbor1.append(distances[i][0])
    return neighbor1
 
    
data = X1
neighbor1 = neighbor1(data, data[0], 10)

for neighbor in neighbor1:
    print(neighbor)
# Out:
# [-1.21644785  2.05848389  1.72383351  0.54599482  1.44386319 -1.61702694
#  -1.03924073  1.72190475 -1.74860387  1.75114361]
# [-1.50961234  1.66783478  0.47379626  1.55251026  0.02435629 -1.31846672
#  -0.67640805  1.5967212   0.06914085 -0.52726575]
# [-1.05738939 -0.06374617  0.56023043 -0.10785592  0.39698775 -0.60735472
#  -1.08811951  0.71741358 -0.04461029  1.15022774]
# [-0.51583025  0.58104793  0.53948164  0.66451303  0.1455225  -0.97386557
#   0.45260335  1.62736195  0.64829523 -1.18299696]
# [-0.34579408  1.16602199 -0.05116181  0.93278709  1.01236038 -0.16457301
#   1.02424075  2.36450019 -0.07448322 -0.22000937]
# [-0.18882973 -0.58131708  0.02996426  0.79568041  0.60276666 -0.98828236
#  -1.49993101  2.45866821 -0.3990372  -0.16479813]
# [ 0.74375637  1.04906212  0.57136111  1.71940526  1.0193549  -1.18505795
#   0.03934096 -0.22290914 -0.09269164 -0.24550885]
# [-1.65796665  0.36072751  0.81848552 -0.5491276   0.12427513  0.76818589
# ...

# %%
# When k = 100

from math import sqrt

def dist_between(a, b):
    dist_between = 0.0
    
    for i in range(len(a)-1):
        dist_between += (a[i] - b[i])**2
    return sqrt(dist_between)
 
def neighbor1(train, test, knn_neighbors):
    distances = list()
    
    for train_row in train:
        dist = dist_between(test, train_row)
        distances.append((train_row, dist))
    distances.sort(key=lambda tup: tup[1])
    neighbor1 = list()
    
    for i in range(knn_neighbors):
        neighbor1.append(distances[i][0])
    return neighbor1
 
    
data = X1
neighbor1 = neighbor1(data, data[0], 100)

for neighbor in neighbor1:
    print(neighbor)
# Out:
# [-1.21644785  2.05848389  1.72383351  0.54599482  1.44386319 -1.61702694
#  -1.03924073  1.72190475 -1.74860387  1.75114361]
# [-1.50961234  1.66783478  0.47379626  1.55251026  0.02435629 -1.31846672
#  -0.67640805  1.5967212   0.06914085 -0.52726575]
# [-1.05738939 -0.06374617  0.56023043 -0.10785592  0.39698775 -0.60735472
#  -1.08811951  0.71741358 -0.04461029  1.15022774]
# [-0.51583025  0.58104793  0.53948164  0.66451303  0.1455225  -0.97386557
#   0.45260335  1.62736195  0.64829523 -1.18299696]
# [-0.34579408  1.16602199 -0.05116181  0.93278709  1.01236038 -0.16457301
#   1.02424075  2.36450019 -0.07448322 -0.22000937]
# [-0.18882973 -0.58131708  0.02996426  0.79568041  0.60276666 -0.98828236
#  -1.49993101  2.45866821 -0.3990372  -0.16479813]
# [ 0.74375637  1.04906212  0.57136111  1.71940526  1.0193549  -1.18505795
#   0.03934096 -0.22290914 -0.09269164 -0.24550885]
# [-1.65796665  0.36072751  0.81848552 -0.5491276   0.12427513  0.76818589
# ...

# %%
#https://www.datacamp.com/community/tutorials/k-nearest-neighbor-classification-scikit-learn


from itertools import product

p = X1[:,[0,2]] 
q = y1

# Setting the decisions boundaries i.e., k to 1, 10, 100 and 20
a1 = KNeighborsClassifier(n_neighbors=1)
b1 = KNeighborsClassifier(n_neighbors=10)
c1 = KNeighborsClassifier(n_neighbors=100)
d1 = KNeighborsClassifier(n_neighbors=20)
a1.fit(p,q)
b1.fit(p,q)
c1.fit(p,q)
d1.fit(p,q)



# Plotting decision regions
x_min, x_max = p[:, 0].min() - 1, p[:, 0].max() + 1
y_min, y_max = p[:, 1].min() - 1, p[:, 1].max() + 1
aa, bb = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))


f, v = plt.subplots(2, 2, sharex="col", sharey="row", figsize=(10, 3))

for idx, clf, tt in zip(
    product([0, 1], [0, 1]),
    [a1,b1,c1,d1],
    ["KNN (k=1)","KNN (k=10)","KNN (k=100)", "KNN (k=20)"],
):

    Z = clf.predict(np.c_[aa.ravel(), bb.ravel()])
    Z = Z.reshape(xx.shape)

    v[idx[0], idx[1]].contourf(aa, bb, Z, alpha=0.7)
    v[idx[0], idx[1]].scatter(X1[:, 0], X1[:, 1], c=y1, s=40, cmap = 'inferno')
    v[idx[0], idx[1]].set_title(tt)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/np/x99l3qf95yj2gj7kh2fbrwmm0000gn/T/ipykernel_66295/2260739221.py in <module>
#      13 #d1 = KNeighborsClassifier(n_neighbors=20)
#      14 a1.fit(p,q)
# ---> 15 b1.fit(p,q)
#      16 c1.fit(p,q)
#      17 d1.fit(p,q)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py in fit(self, X, y)
#     196         self.weights = _check_weights(self.weights)
#     197
# --> 198         return self._fit(X, y)
#     199
#     200     def predict(self, X):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_base.py in _fit(self, X, y)
#     418                     self.outputs_2d_ = True
#     419
# --> 420                 check_classification_targets(y)
#     421                 self.classes_ = []
#     422                 self._y = np.empty(y.shape, dtype=int)
#
# ...

# %%
from itertools import product
from sklearn.neighbors import KNeighborsRegressor

# Setting the decisions boundaries i.e., k to 1, 10, 100 and 20
c = X1[:,[0,2]] 
d = y1

a1 = KNeighborsRegressor(n_neighbors=1)
b1 = KNeighborsRegressor(n_neighbors=10)
c1 = KNeighborsRegressor(n_neighbors=100)
d1 = KNeighborsRegressor(n_neighbors=20)
a1.fit(p,q)
b1.fit(p,q)
c1.fit(p,q)
d1.fit(p,q)



x_min, x_max = c[:, 0].min() - 1, c[:, 0].max() + 1
y_min, y_max = c[:, 1].min() - 1, c[:, 1].max() + 1
aa, bb = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))

f, v = plt.subplots(2, 2, sharex="col", sharey="row", figsize=(10, 3))
for i, j, k in zip(
    product([0, 1], [0, 1]),
    [a1,b1,c1,d1],
    ["KNN (k=1)","KNN (k=10)","KNN (k=100)","KNN (k=20)"],
):
    Z = j.predict(np.c_[aa.ravel(), bb.ravel()])
    Z = Z.reshape(aa.shape)
    v[i[0], i[1]].contourf(aa, bb, Z, alpha=0.9)
    v[i[0], i[1]].scatter(X1[:, 0], X1[:, 1], c=y1, s=40, cmap = 'YlOrBr')
    v[i[0], i[1]].set_title(k)

plt.show()
